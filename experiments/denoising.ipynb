# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread("./HR _image.png")
img = img[...,::-1]

# %%
# %timeit denoise_1 = cv2.fastNlMeansDenoisingColored(img, None, 10, 3, 7, 21)
# Out:
# 681 ms ± 55.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit median = cv2.medianBlur(img,5)
# Out:
# 5.32 ms ± 211 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit blur = cv2.GaussianBlur(img,(5,5),0)
# Out:
# 3.56 ms ± 305 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit average = cv2.blur(img,(5,5))
# Out:
# 2.63 ms ± 83.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit bilateral = cv2.bilateralFilter(img,9,75,75)
# Out:
# 39.9 ms ± 4.09 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
denoise_1 = cv2.fastNlMeansDenoisingColored(img, None, 10, 3, 7, 21)

# %%
median = cv2.medianBlur(img,5)

# %%
blur = cv2.GaussianBlur(img,(5,5),0)

# %%
average = cv2.blur(img,(5,5))

# %%
bilateral = cv2.bilateralFilter(img,9,75,75)

# %%
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()
